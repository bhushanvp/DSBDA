# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./DSBDALExam_DataSets/HeartDisease/Cleavland.csv", header=None)

# %%
col = "age","sex","cp","trestbps","chol","fbs","restecg","thalach","exang","oldpeak","slope","ca","thal","num"
col_names = {}
j = 0
for i in col:
    col_names[j] = i
    j = j+1
df = df.rename(columns = col_names)
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0     63    1   1       145   233    1        2      150      0      2.3  \
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope ca thal  num
# 0        3  0    6    0
# 1        2  3    3    2
# ...

# %%
import seaborn as sns
import matplotlib as plt

# %%
df.hist(figsize=(15,10), bins=10)
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'cp'}>],
#        [<Axes: title={'center': 'trestbps'}>,
#         <Axes: title={'center': 'chol'}>,
#         <Axes: title={'center': 'fbs'}>],
#        [<Axes: title={'center': 'restecg'}>,
#         <Axes: title={'center': 'thalach'}>,
#         <Axes: title={'center': 'exang'}>],
#        [<Axes: title={'center': 'oldpeak'}>,
#         <Axes: title={'center': 'slope'}>,
#         <Axes: title={'center': 'num'}>]], dtype=object)

# %%
sns.histplot(data=df, y="oldpeak", x="age", bins=10)
# Out:
# <Axes: xlabel='age', ylabel='oldpeak'>

# %%
df["age"].hist(df["num"], bins=10)
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#        [<Axes: title={'center': '2'}>, <Axes: title={'center': '3'}>],
#        [<Axes: title={'center': '4'}>, <Axes: >]], dtype=object)

# %%
sns.scatterplot(x=df["oldpeak"], y=df["thalach"]/30)
sns.scatterplot(x=df["oldpeak"], y=df["age"]/10)
# sns.scatterplot(x=df["age"], y=df["thalach"]/20)
# Out:
# <Axes: xlabel='oldpeak', ylabel='thalach'>

# %%
sns.barplot(x=df["cp"], y=df["oldpeak"])
# Out:
# <Axes: xlabel='cp', ylabel='oldpeak'>

# %%
sns.barplot(x=df["cp"], y=(df["age"]-df["age"].min())/(df["age"].max()-df["age"].min()))
# Out:
# <Axes: xlabel='cp', ylabel='age'>

# %%
sns.lineplot(x=df["cp"], y=df["age"])
# Out:
# <Axes: xlabel='cp', ylabel='age'>
